# %%
import pandas as pd

# %%
df = pd.read_csv("demo_movie.csv")
df
# Out:
#     movie_id                     title  vote_average  popularity  vote_count  \
# 0         99                       NaN           8.5         NaN         NaN
# 1          4                    Avatar           7.8        82.3     15000.0
# 2          1                 Inception           8.8        90.2     21000.0
# 3          2                The Matrix           8.7        88.5     18000.0
# 4          3              Interstellar           8.6        85.0     19500.0
# 5          5             Spirited Away           8.5        75.6     13000.0
# 6          6             The Godfather           9.2        70.1     21000.0
# 7          7           The Dark Knight           9.0        95.0     22000.0
# 8          8                  Parasite           8.6        78.3     14000.0
# 9          9  The Shawshank Redemption           9.3        85.7     24000.0
# 10        10             The Lion King           8.5        80.0     17000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      11 non-null     int64
#  1   title         10 non-null     object
#  2   vote_average  11 non-null     float64
#  3   popularity    10 non-null     float64
#  4   vote_count    10 non-null     float64
#  5   budget        10 non-null     float64
#  6   revenue       10 non-null     float64
#  7   runtime       10 non-null     float64
#  8   genres        9 non-null      object
#  9   keywords      10 non-null     object
#  10  companies     10 non-null     object
#  11  languages     10 non-null     object
#  12  countries     10 non-null     object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.2+ KB

# %%
dataset = pd.read_csv("cleaned_data.csv")
dataset
# Out:
#            id                         title  vote_average  vote_count  \
# 0           5                    Four Rooms         5.784        2436
# 1           6                Judgment Night         6.533         302
# 2          12                  Finding Nemo         7.824       18061
# 3          13                  Forrest Gump         8.477       25409
# 4          15                  Citizen Kane         8.015        5034
# ...       ...                           ...           ...         ...
# 8436  1418175  A solution that pleases all.         6.000           1
# 8437  1440649           Who’s Watching Who?        10.000           1
# 8438  1448288                        Karina        10.000           1
# 8439  1449949                       Reverie         9.000           1
# 8440  1469993                 Metal Strings        10.000           1
#
#         status              release_date    revenue  runtime  adult    budget  \
# ...

# %%
dataset[["title", "genres", "keywords", "overview"]]
# Out:
#                              title                       genres  \
# 0                       Four Rooms                       Comedy
# 1                   Judgment Night      Action, Crime, Thriller
# 2                     Finding Nemo            Animation, Family
# 3                     Forrest Gump       Comedy, Drama, Romance
# 4                     Citizen Kane               Mystery, Drama
# ...                            ...                          ...
# 8436  A solution that pleases all.                        Drama
# 8437           Who’s Watching Who?                Comedy, Drama
# 8438                        Karina                  Documentary
# 8439                       Reverie              Drama, Thriller
# 8440                 Metal Strings  Documentary, Music, History
#
#                                                keywords  \
# 0     hotel, new year's eve, witch, bet, sperm, hote...
# 1     drug dealer, chicago, illinois, escape, one ni...
# ...

# %%
real_data = pd.read_csv("D:/Github_ThisPC/TMDB_RecoFlow/airflow/data/cbf_movie.csv")
real_data.head()
# Out:
#                                  title                      genres  \
# 0                  Sons of Rizk (2015)       Crime, Comedy, Action
# 1                     Capernaum (2018)                       Drama
# 2                   Amod Faqrey (2016)              Family, Comedy
# 3                          Mako (2021)  Thriller, Adventure, Drama
# 4  A solution that pleases all. (1986)                       Drama
#
#                                             keywords  \
# 0                  sibling relationship, crime spree
# 1  child bride, slum, poverty, refugee, life in t...
# 2              amod faqrey, spinal column, عمود فقري
# 3                          shark, shark attack, mako
# 4                            family dynamics, tenant
#
#                                             overview
# 0  Four brothers committing crimes with a promise...
# 1  Zain, a 12-year-old boy scrambling to survive ...
# 2  A young man in his fourth decade looking for a...
# ...

# %%
real_data.count()
# Out:
# title       8441
# genres      8441
# keywords    8441
# overview    8441
# dtype: int64

# %%
real_data_dup = real_data[real_data.duplicated('title', keep=False)]
real_data_dup
# Out:
#            title  genres         keywords  \
# 823  Dany (2018)  Comedy    caméra cachée
# 840  Dany (2018)   Drama  gay theme, lgbt
#
#                                               overview
# 823  Dany, the king of petty thefts, did not wait u...
# 840  The descent into hell of Dany, a young homeles...

# %%
real_data[real_data["title"] == "Dany"]
# Out:
#             title  genres                                           keywords  \
# 31    Poltergeist  Horror  haunted house, poltergeist, remake, duringcred...
# 2178  Poltergeist  Horror  haunted, ghostbuster, power of goodness, paran...
#
#                                                overview
# 31    A family's suburban home is invaded by angry s...
# 2178  Steve Freeling lives with his wife, Diane, and...

# %%
df = pd.read_csv("demo_movie.csv")

df[5:].to_parquet('cbf_movie_demo2.parquet')

# %%
demo1 = df[1:5]
demo1.to_parquet('cbf_movie_demo1.parquet')

# %%
demo2 = df[5:]
demo2.to_parquet('cbf_movie_demo2.parquet')

# %%
df1= pd.read_parquet('cbf_movie_demo1.parquet')
df1
# Out:
#    movie_id         title  vote_average  popularity  vote_count       budget  \
# 1         4        Avatar           7.8        82.3     15000.0  237000000.0
# 2         1     Inception           8.8        90.2     21000.0  160000000.0
# 3         2    The Matrix           8.7        88.5     18000.0   63000000.0
# 4         3  Interstellar           8.6        85.0     19500.0  165000000.0
#
#         revenue  runtime                      genres         keywords  \
# 1  2.800000e+09    162.0                        None        rebellion
# 2  8.290000e+08    148.0     Action, Science Fiction            dream
# 3  4.650000e+08    136.0                      Action  virtual reality
# 4  6.770000e+08    169.0  Science Fiction, Adventure            space
#
#             companies languages      countries
# 1    20th Century Fox   English  United States
# 2        Warner Bros.   English  United States
# 3        Warner Bros.   English  United States
# ...

# %%
df2= pd.read_parquet('cbf_movie_demo2.parquet')
df2
# Out:
#     movie_id                     title  vote_average  popularity  vote_count  \
# 5          5             Spirited Away           8.5        75.6     13000.0
# 6          6             The Godfather           9.2        70.1     21000.0
# 7          7           The Dark Knight           9.0        95.0     22000.0
# 8          8                  Parasite           8.6        78.3     14000.0
# 9          9  The Shawshank Redemption           9.3        85.7     24000.0
# 10        10             The Lion King           8.5        80.0     17000.0
#
#          budget       revenue  runtime         genres      keywords  \
# 5    15000000.0  3.550000e+08    125.0        Fantasy         magic
# 6     6000000.0  2.460000e+08    175.0          Crime         mafia
# 7   185000000.0  1.005000e+09    152.0  Action, Crime         joker
# 8    11400000.0  2.580000e+08    132.0          Drama  class divide
# 9    25000000.0  7.300000e+07    142.0          Drama        prison
# ...

# %%
final_df = pd.read_parquet('final_cbf_movie.parquet')
final_df
# Out:
#    movie_id                     title  vote_average  popularity  vote_count  \
# 0         4                    Avatar           7.8        82.3     15000.0
# 1         1                 Inception           8.8        90.2     21000.0
# 2         2                The Matrix           8.7        88.5     18000.0
# 3         3              Interstellar           8.6        85.0     19500.0
# 4         5             Spirited Away           8.5        75.6     13000.0
# 5         6             The Godfather           9.2        70.1     21000.0
# 6         7           The Dark Knight           9.0        95.0     22000.0
# 7         8                  Parasite           8.6        78.3     14000.0
# 8         9  The Shawshank Redemption           9.3        85.7     24000.0
# 9        10             The Lion King           8.5        80.0     17000.0
#
#         budget       revenue  runtime                      genres  \
# ...
