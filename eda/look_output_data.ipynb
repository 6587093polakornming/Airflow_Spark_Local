# %%
import pandas as pd

# %%
df = pd.read_csv("demo_movie.csv")
df
# Out:
#     movie_id                     title  vote_average  popularity  vote_count  \
# 0         99                       NaN           8.5         NaN         NaN
# 1          4                    Avatar           7.8        82.3     15000.0
# 2          1                 Inception           8.8        90.2     21000.0
# 3          2                The Matrix           8.7        88.5     18000.0
# 4          3              Interstellar           8.6        85.0     19500.0
# 5          5             Spirited Away           8.5        75.6     13000.0
# 6          6             The Godfather           9.2        70.1     21000.0
# 7          7           The Dark Knight           9.0        95.0     22000.0
# 8          8                  Parasite           8.6        78.3     14000.0
# 9          9  The Shawshank Redemption           9.3        85.7     24000.0
# 10        10             The Lion King           8.5        80.0     17000.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      11 non-null     int64
#  1   title         10 non-null     object
#  2   vote_average  11 non-null     float64
#  3   popularity    10 non-null     float64
#  4   vote_count    10 non-null     float64
#  5   budget        10 non-null     float64
#  6   revenue       10 non-null     float64
#  7   runtime       10 non-null     float64
#  8   genres        9 non-null      object
#  9   keywords      10 non-null     object
#  10  companies     10 non-null     object
#  11  languages     10 non-null     object
#  12  countries     10 non-null     object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.2+ KB
